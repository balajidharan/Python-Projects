# %% [markdown]
# # IRIS DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = pd.read_csv('D:/iris.data')
iris.columns=['Sepal_length', 'Sepal_width','Petal_length','Petal_width','Iris Name']
print(iris.head())
print(iris.describe())
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width    Iris Name
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa
#        Sepal_length  Sepal_width  Petal_length  Petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.isnull().sum()
# Out:
# Sepal_length    0
# Sepal_width     0
# Petal_length    0
# Petal_width     0
# Iris Name       0
# dtype: int64

# %%
iris2 = iris.drop_duplicates(subset ='Iris Name')
iris2
# Out:
#     Sepal_length  Sepal_width  Petal_length  Petal_width        Iris Name
# 0            4.9          3.0           1.4          0.2      Iris-setosa
# 49           7.0          3.2           4.7          1.4  Iris-versicolor
# 99           6.3          3.3           6.0          2.5   Iris-virginica

# %%
iris.value_counts('Iris Name')
# Out:
# Iris Name
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# dtype: int64

# %%
sns.countplot(x='Iris Name', data=iris, )
plt.show()

# %%
Isetosa = iris.loc[iris['Iris Name'] == 'Iris-setosa']
Ivirginica = iris.loc[iris['Iris Name'] == 'Iris-virginica']
Iversicolor = iris.loc[iris['Iris Name'] == 'Iris-versicolor']
plt.plot(Isetosa['Petal_length'],np.zeros_like(Isetosa['Petal_length']), 'o')
plt.plot(Ivirginica['Petal_length'],np.zeros_like(Ivirginica['Petal_length']), 'o')
plt.plot(Iversicolor['Petal_length'],np.zeros_like(Iversicolor['Petal_length']), 'o')
plt.grid()
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris,hue='Iris Name',height=4) \
    .map(plt.scatter,'Sepal_length','Sepal_width') \
    .add_legend()
plt.show()

# %%
# x = iris.Sepal_length
# y = iris.Sepal_width
# z = iris.Petal_width

# %%
# from mpl_toolkit.mplot3d import Axes3D
# fig = plt.figure()
# ax = fig.add_sub[lot(111,projection='3d')
#  ax.scatter(x, y, z,c=r,marker='o')
# ax.set_xlabel('SEPAL LENGTH')
# ax.set_xlabel('SEPAL WIDTH')
# ax.set_xlabel('PETAL WIDTH')
# plt.show()

# %%
sns.pairplot(iris,hue='Iris Name', height=2)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10))
  
axes[0,0].set_title('SEPAL LENGTH')
axes[0,0].hist(iris['Sepal_length'], bins=7)
  
axes[0,1].set_title('SEPAL WIDTH')
axes[0,1].hist(iris['Sepal_width'], bins=5);
  
axes[1,0].set_title('PETAL LENGTH')
axes[1,0].hist(iris['Petal_length'], bins=6);
  
axes[1,1].set_title("PETAL WIDTH")
axes[1,1].hist(iris['Petal_width'], bins=6);

# %%
plot = sns.FacetGrid(iris, hue='Iris Name')
plot.map(sns.histplot, "Sepal_length").add_legend()
  
plot = sns.FacetGrid(iris, hue='Iris Name')
plot.map(sns.histplot, "Sepal_width").add_legend()
  
plot = sns.FacetGrid(iris, hue='Iris Name')
plot.map(sns.histplot, "Petal_length").add_legend()
  
plot = sns.FacetGrid(iris, hue='Iris Name')
plot.map(sns.histplot, "Petal_width").add_legend()
  
plt.show()

# %%
iris.corr()
# Out:
#               Sepal_length  Sepal_width  Petal_length  Petal_width
# Sepal_length      1.000000    -0.103784      0.871283     0.816971
# Sepal_width      -0.103784     1.000000     -0.415218    -0.350733
# Petal_length      0.871283    -0.415218      1.000000     0.962314
# Petal_width       0.816971    -0.350733      0.962314     1.000000

# %%
iris2.corr()
# Out:
#               Sepal_length  Sepal_width  Petal_length  Petal_width
# Sepal_length      1.000000     0.785714      0.818999     0.673417
# Sepal_width       0.785714     1.000000      0.998443     0.986414
# Petal_length      0.818999     0.998443      1.000000     0.975713
# Petal_width       0.673417     0.986414      0.975713     1.000000

# %%
sns.heatmap(iris.corr(),annot = True)
plt.show()

# %%
def graph(y):
    sns.boxplot(x='Iris Name', y=y, data=iris)
plt.figure(figsize=(10,10))
plt.subplot(221)
graph('Sepal_length')
  
plt.subplot(222)
graph('Sepal_width')
  
plt.subplot(223)
graph('Petal_length')
  
plt.subplot(224)
graph('Petal_width')
  
plt.show()

# %%
sns.boxplot(x='Sepal_width', data=iris)
# Out:
# <AxesSubplot:xlabel='Sepal_width'>

# %%
import sklearn
from sklearn.datasets import load_boston
Q1 = np.percentile(iris['Sepal_width'], 25,
                interpolation = 'midpoint')
  
Q3 = np.percentile(iris['Sepal_width'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1
  
print("Old Shape: ", iris.shape)
upper = np.where(iris['Sepal_width'] >= (Q3+1.5*IQR))
lower = np.where(iris['Sepal_width'] <= (Q1-1.5*IQR))
iris.drop(upper[0], inplace = True)
iris.drop(lower[0], inplace = True)
print("New Shape: ", iris.shape)
sns.boxplot(x='Sepal_width', data=iris)
# Out:
# Old Shape:  (145, 5)
# New Shape:  (145, 5)
# <AxesSubplot:xlabel='Sepal_width'>

# %% [markdown]
# ### END
